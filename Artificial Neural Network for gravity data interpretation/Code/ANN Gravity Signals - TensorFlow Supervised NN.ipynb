# %%
# Clear all variables first
#%reset

# Used for various useful applications, such as basic math and arrays
import numpy as np

# Used for various plotting applications
import matplotlib.pyplot as plt

# Used for useful handling of data and splitting of data
import pandas as pd

# Useful package for machine learning in general
import tensorflow as tf

# Used for training and building the artificial neural network
from tensorflow import keras
from tensorflow.keras import layers


class Station_point:
    def __init__(self, x, z, R, rho, q, m):
        G = 6.67408 *10**-11
        self.A = 4/3*np.pi*G*rho*R**3
        self.g = self.A*z**m/(x**2+z**2)**q
    def norm_g(self, g0):
        self.g0 = self.g/g0

def Measurement_generation(R,rho,m,q,z,Num_points):
    Centre_x = 0
    Centre_y = 0
    p0 = Station_point(0,z,R,rho,q,m)

    Input_data_list_NN = [[0 for x in range (0,2)] for y in range(0,Num_points)]
    Station_points_list = [0 for x in range (0,Num_points)]

    for a in range (0,Num_points):
        Ran_x = np.abs(50*np.random.randn())
        p = Station_point(Ran_x,z,R,rho,q,m)
        p.norm_g(p0.g)
        Input_data_list_NN[a][0] = Ran_x
        Input_data_list_NN[a][1] = p.g0
        Station_points_list[a] = p
    
    Max_x = 0
    for a in range (0,Num_points):
        if (np.max(Input_data_list_NN[a][0]) > Max_x):
            Max_x = np.max(Input_data_list_NN[a][0])
#     for a in range (0,Num_points):
#         Input_data_list_NN[a][0] = Input_data_list_NN[a][0]/Max_x 
    
    return [Input_data_list_NN,Max_x]     

# sample sample
Maxest_x = 0
Maxest_z = 0
X_array = [0 for a in range(0,50000)]
y_array = [0 for a in range(0,50000)]
q_options = [1/2,1,3/2]
index = 0
for a in range(0,2000):
    ran_z = np.abs(150*np.random.rand())
    ran_q_index = np.round(np.abs(2*np.random.rand()))
    ran_q = q_options[np.int(ran_q_index)]
    R = 10
    rho = 2500
    m = 1
    if ran_q==1/2:
        m = -1
    [X,Max_x] = Measurement_generation(R,rho,m,ran_q,ran_z,25)
    if (Max_x > Maxest_x):
        Maxest_x = Max_x
    if (ran_z > Maxest_z):
        Maxest_z = ran_z
    
    y = [[0 for x in range (0,2)] for y in range(0,25)]
    for x in range(0,25):
        y[x][0] = ran_z
        y[x][1] = ran_q
    
    for x in range(0,25):
        X_array[index + x] = X[x]
        y_array[index + x] = y[x]
    index = index + 25
        
for a in range(0,50000):
    X_array[a][0] = X_array[a][0]/Maxest_x
    y_array[a][0] = y_array[a][0]/Maxest_z
    
# print(X_array)
# print(y_array)

features = X_array
labels = y_array
# # Load the Features; list of Time of Flight (0th column), Departure time (1st column) and Arrival time (2nd column)
# # Time of Flight in seconds, Departure time in seconds since 1/1/2020 1:30 PM, Arrival time in seconds since 1/1/2020 1:30 PM
# features=np.loadtxt("Total_Features.txt")
# # Load the Labels; list of Delta V needed at Earth and Delta V needed at Mars
# # Optionally: sum them for a different label
# labels=np.loadtxt("Total_Labels.txt")

# %%
# Right now, all features and all labels are used. This can be changed;
# Either one of the flight time, departure time and arrival time is not necessary
# The labels are related, but the ANN doesn't have to output both
# Delta V0 is the Delta V needed of the spacecraft at location Earth
# Delta V1 is the Delta V needed of the spacecraft at location Mars

# Optional different loadings: take Delta V1 as label, or the total Delta V
# 
pdata = pd.DataFrame({'Distance':np.transpose(features)[0],'Gravity':np.transpose(features)[1],'Depth':np.transpose(labels)[0],'Shape':np.transpose(labels)[1]})
# pdata = pd.DataFrame({'Flight time':features[:,0],'Departure time':features[:,1],'Arrival time':features[:,2],'Delta V1':labels[:,1]})
# pdata = pd.DataFrame({'Flight time':features[:,0],'Departure time':features[:,1],'Arrival time':features[:,2],'Total V':(labels[:,0]+labels[:,1])})


# The data set is divided into a training data set and a testing data set
# Currently, the fraction is 80% training and 20% testing. This can be changed, but it is recommended to have more training than testing data
train_dataset = pdata.sample(frac=0.8, random_state=0)
test_dataset = pdata.drop(train_dataset.index)

# Here, we 'pop out' the labels from the features to use them independently
# regressor = tf.contrib.learn.DNNRegressor(feature_columns=feature_cols,
#                                         label_dimension=3,
#                                         hidden_units=[10, 10],
#                                         model_dir="/tmp/boston_model")

train_labels = pd.DataFrame([train_dataset.pop(x) for x in ['Depth', 'Shape']]).T
test_labels = pd.DataFrame([test_dataset.pop(x) for x in ['Depth', 'Shape']]).T

# train_label_1 = train_dataset.pop('Depth','Shape')
# test_label_1 = test_dataset.pop('Depth','Shape')

print(train_labels)

print(type(train_labels))
# Optionally different loadings: pop out Delta V1 or total Delta V
# train_labels = train_dataset.pop('Delta V1')
# train_labels = train_dataset.pop('Delta V1')
# train_labels = train_dataset.pop('Delta V1')
# train_labels = train_dataset.pop('Delta V1')

# Now, only features are in the dataset. Rename for clearness
train_features = train_dataset
test_features = test_dataset

# Definition of a normalization function to normalize features 
# def norm(x):
#   return (x - np.mean(x)) / np.std(x)

# # The data sets for training and testing data are normalized
# normed_train_features = norm(train_features)
# normed_test_features = norm(test_features)

print(len(train_labels))
print(len(test_labels))
# Out:
#           Depth  Shape
# 11841  0.286658    1.0
# 19602  0.897695    1.5
# 45519  0.059295    1.0
# 25747  0.456827    1.5
# 42642  0.312501    0.5
# ...         ...    ...
# 8809   0.306691    0.5
# 47565  0.531497    1.0
# 412    0.015625    0.5
# 12293  0.289451    1.5
# 17267  0.385885    1.0
#
# [40000 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# 40000
# 10000

# %%
# The model itself is built here. Different options are available. Listed below are possibilities:

# Change the number of neurons per layer. Default is 64, somewhat lower and higher can be tested
# Change the number of layers. Default is 4, this can be changed
# Change the activation function. Default is tanh
# Change the loss function. Default is mse, optimizer: adam, accuracy: metrics

def build_model(): 
    model = keras.Sequential([    
        layers.Dense(64, activation='relu', input_shape=[len(train_features.keys())]),  
        layers.Dense(2)
    ])

    
    model.compile(loss='mse',
                optimizer='adam',
                metrics=['accuracy','mae','mse'])
    
    ## Different possible loss function:
    # model.compile(loss='mse',              
    # optimizer=keras.optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True),                                       
    # metrics=['accuracy']) 
    return model

# %%
# Build the model and save this as 'model'
model = build_model()

# %%
# Training of the ANN, or 'fitting'. Default input are normalized training features, training labels, a validation split of 0.2
# The number of epochs should be changed per combination of settings; at some point the model reaches a platform at which it doesn't improve anymore. This should be the maximum amount of epochs
# From previous results, this is usually between 10 and 1000
history = model.fit(train_features, train_labels, validation_split=0.2, epochs=100)
# Out:
# Train on 32000 samples, validate on 8000 samples
# WARNING:tensorflow:From C:\Users\frank\Anaconda3\envs\specialTopics\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 32000/32000 [==============================] - 2s 52us/sample - loss: 0.1248 - acc: 0.8281 - mean_absolute_error: 0.2509 - mean_squared_error: 0.1248 - val_loss: 0.0767 - val_acc: 0.8811 - val_mean_absolute_error: 0.2068 - val_mean_squared_error: 0.0767
# Epoch 2/100
# 32000/32000 [==============================] - 1s 43us/sample - loss: 0.0743 - acc: 0.8826 - mean_absolute_error: 0.2032 - mean_squared_error: 0.0743 - val_loss: 0.0752 - val_acc: 0.8855 - val_mean_absolute_error: 0.2052 - val_mean_squared_error: 0.0752
# Epoch 3/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0731 - acc: 0.8878 - mean_absolute_error: 0.2006 - mean_squared_error: 0.0731 - val_loss: 0.0738 - val_acc: 0.8901 - val_mean_absolute_error: 0.2009 - val_mean_squared_error: 0.0738
# Epoch 4/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0715 - acc: 0.8939 - mean_absolute_error: 0.1968 - mean_squared_error: 0.0715 - val_loss: 0.0720 - val_acc: 0.8986 - val_mean_absolute_error: 0.1973 - val_mean_squared_error: 0.0720
# Epoch 5/100
# 32000/32000 [==============================] - 1s 45us/sample - loss: 0.0699 - acc: 0.8996 - mean_absolute_error: 0.1936 - mean_squared_error: 0.0699 - val_loss: 0.0704 - val_acc: 0.9029 - val_mean_absolute_error: 0.1938 - val_mean_squared_error: 0.0704
# Epoch 6/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0686 - acc: 0.9034 - mean_absolute_error: 0.1913 - mean_squared_error: 0.0686 - val_loss: 0.0692 - val_acc: 0.9065 - val_mean_absolute_error: 0.1928 - val_mean_squared_error: 0.0692
# Epoch 7/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0675 - acc: 0.9067 - mean_absolute_error: 0.1895 - mean_squared_error: 0.0675 - val_loss: 0.0682 - val_acc: 0.9106 - val_mean_absolute_error: 0.1917 - val_mean_squared_error: 0.0682
# Epoch 8/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0665 - acc: 0.9091 - mean_absolute_error: 0.1882 - mean_squared_error: 0.0665 - val_loss: 0.0674 - val_acc: 0.9158 - val_mean_absolute_error: 0.1900 - val_mean_squared_error: 0.0674
# Epoch 9/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0658 - acc: 0.9109 - mean_absolute_error: 0.1867 - mean_squared_error: 0.0658 - val_loss: 0.0672 - val_acc: 0.9189 - val_mean_absolute_error: 0.1906 - val_mean_squared_error: 0.0672
# Epoch 10/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0652 - acc: 0.9112 - mean_absolute_error: 0.1859 - mean_squared_error: 0.0652 - val_loss: 0.0661 - val_acc: 0.9136 - val_mean_absolute_error: 0.1870 - val_mean_squared_error: 0.0661
# Epoch 11/100
# 32000/32000 [==============================] - 1s 42us/sample - loss: 0.0646 - acc: 0.9131 - mean_absolute_error: 0.1844 - mean_squared_error: 0.0646 - val_loss: 0.0656 - val_acc: 0.9141 - val_mean_absolute_error: 0.1854 - val_mean_squared_error: 0.0656
# Epoch 12/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0641 - acc: 0.9140 - mean_absolute_error: 0.1829 - mean_squared_error: 0.0641 - val_loss: 0.0651 - val_acc: 0.9215 - val_mean_absolute_error: 0.1852 - val_mean_squared_error: 0.0651
# Epoch 13/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0637 - acc: 0.9137 - mean_absolute_error: 0.1817 - mean_squared_error: 0.0637 - val_loss: 0.0648 - val_acc: 0.9178 - val_mean_absolute_error: 0.1847 - val_mean_squared_error: 0.0648
# Epoch 14/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0633 - acc: 0.9155 - mean_absolute_error: 0.1807 - mean_squared_error: 0.0633 - val_loss: 0.0641 - val_acc: 0.9183 - val_mean_absolute_error: 0.1824 - val_mean_squared_error: 0.0641
# Epoch 15/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0630 - acc: 0.9166 - mean_absolute_error: 0.1797 - mean_squared_error: 0.0630 - val_loss: 0.0639 - val_acc: 0.9174 - val_mean_absolute_error: 0.1820 - val_mean_squared_error: 0.0639
# Epoch 16/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0627 - acc: 0.9182 - mean_absolute_error: 0.1789 - mean_squared_error: 0.0627 - val_loss: 0.0634 - val_acc: 0.9236 - val_mean_absolute_error: 0.1800 - val_mean_squared_error: 0.0634
# Epoch 17/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0624 - acc: 0.9207 - mean_absolute_error: 0.1778 - mean_squared_error: 0.0624 - val_loss: 0.0639 - val_acc: 0.9233 - val_mean_absolute_error: 0.1840 - val_mean_squared_error: 0.0639
# Epoch 18/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0622 - acc: 0.9191 - mean_absolute_error: 0.1774 - mean_squared_error: 0.0622 - val_loss: 0.0638 - val_acc: 0.9087 - val_mean_absolute_error: 0.1821 - val_mean_squared_error: 0.0638
# Epoch 19/100
# 32000/32000 [==============================] - 1s 42us/sample - loss: 0.0620 - acc: 0.9201 - mean_absolute_error: 0.1769 - mean_squared_error: 0.0620 - val_loss: 0.0627 - val_acc: 0.9258 - val_mean_absolute_error: 0.1792 - val_mean_squared_error: 0.0627
# Epoch 20/100
# 32000/32000 [==============================] - 1s 44us/sample - loss: 0.0618 - acc: 0.9204 - mean_absolute_error: 0.1764 - mean_squared_error: 0.0618 - val_loss: 0.0625 - val_acc: 0.9276 - val_mean_absolute_error: 0.1775 - val_mean_squared_error: 0.0625
# Epoch 21/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0617 - acc: 0.9216 - mean_absolute_error: 0.1762 - mean_squared_error: 0.0617 - val_loss: 0.0637 - val_acc: 0.9246 - val_mean_absolute_error: 0.1781 - val_mean_squared_error: 0.0637
# Epoch 22/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0616 - acc: 0.9221 - mean_absolute_error: 0.1758 - mean_squared_error: 0.0616 - val_loss: 0.0633 - val_acc: 0.9164 - val_mean_absolute_error: 0.1813 - val_mean_squared_error: 0.0633
# Epoch 23/100
# 32000/32000 [==============================] - 1s 44us/sample - loss: 0.0614 - acc: 0.9230 - mean_absolute_error: 0.1756 - mean_squared_error: 0.0614 - val_loss: 0.0622 - val_acc: 0.9220 - val_mean_absolute_error: 0.1763 - val_mean_squared_error: 0.0622
# Epoch 24/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0613 - acc: 0.9225 - mean_absolute_error: 0.1751 - mean_squared_error: 0.0613 - val_loss: 0.0620 - val_acc: 0.9240 - val_mean_absolute_error: 0.1779 - val_mean_squared_error: 0.0620
# Epoch 25/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0612 - acc: 0.9242 - mean_absolute_error: 0.1751 - mean_squared_error: 0.0612 - val_loss: 0.0621 - val_acc: 0.9243 - val_mean_absolute_error: 0.1767 - val_mean_squared_error: 0.0621
# Epoch 26/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0611 - acc: 0.9232 - mean_absolute_error: 0.1747 - mean_squared_error: 0.0611 - val_loss: 0.0624 - val_acc: 0.9239 - val_mean_absolute_error: 0.1794 - val_mean_squared_error: 0.0624
# Epoch 27/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0611 - acc: 0.9245 - mean_absolute_error: 0.1748 - mean_squared_error: 0.0611 - val_loss: 0.0623 - val_acc: 0.9231 - val_mean_absolute_error: 0.1774 - val_mean_squared_error: 0.0623
# Epoch 28/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0610 - acc: 0.9254 - mean_absolute_error: 0.1746 - mean_squared_error: 0.0610 - val_loss: 0.0620 - val_acc: 0.9300 - val_mean_absolute_error: 0.1775 - val_mean_squared_error: 0.0620
# Epoch 29/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0609 - acc: 0.9251 - mean_absolute_error: 0.1743 - mean_squared_error: 0.0609 - val_loss: 0.0615 - val_acc: 0.9270 - val_mean_absolute_error: 0.1766 - val_mean_squared_error: 0.0615
# Epoch 30/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0608 - acc: 0.9254 - mean_absolute_error: 0.1740 - mean_squared_error: 0.0608 - val_loss: 0.0615 - val_acc: 0.9276 - val_mean_absolute_error: 0.1777 - val_mean_squared_error: 0.0615
# Epoch 31/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0607 - acc: 0.9257 - mean_absolute_error: 0.1740 - mean_squared_error: 0.0607 - val_loss: 0.0614 - val_acc: 0.9289 - val_mean_absolute_error: 0.1744 - val_mean_squared_error: 0.0614
# Epoch 32/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0607 - acc: 0.9258 - mean_absolute_error: 0.1736 - mean_squared_error: 0.0607 - val_loss: 0.0623 - val_acc: 0.9218 - val_mean_absolute_error: 0.1795 - val_mean_squared_error: 0.0623
# Epoch 33/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0607 - acc: 0.9261 - mean_absolute_error: 0.1737 - mean_squared_error: 0.0607 - val_loss: 0.0615 - val_acc: 0.9321 - val_mean_absolute_error: 0.1748 - val_mean_squared_error: 0.0615
# Epoch 34/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0606 - acc: 0.9265 - mean_absolute_error: 0.1736 - mean_squared_error: 0.0606 - val_loss: 0.0612 - val_acc: 0.9304 - val_mean_absolute_error: 0.1756 - val_mean_squared_error: 0.0612
# Epoch 35/100
# 32000/32000 [==============================] - 1s 42us/sample - loss: 0.0605 - acc: 0.9258 - mean_absolute_error: 0.1733 - mean_squared_error: 0.0605 - val_loss: 0.0611 - val_acc: 0.9339 - val_mean_absolute_error: 0.1759 - val_mean_squared_error: 0.0611
# Epoch 36/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0605 - acc: 0.9266 - mean_absolute_error: 0.1733 - mean_squared_error: 0.0605 - val_loss: 0.0612 - val_acc: 0.9256 - val_mean_absolute_error: 0.1767 - val_mean_squared_error: 0.0612
# Epoch 37/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0605 - acc: 0.9268 - mean_absolute_error: 0.1733 - mean_squared_error: 0.0605 - val_loss: 0.0625 - val_acc: 0.9308 - val_mean_absolute_error: 0.1758 - val_mean_squared_error: 0.0625
# Epoch 38/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0604 - acc: 0.9269 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0604 - val_loss: 0.0617 - val_acc: 0.9274 - val_mean_absolute_error: 0.1773 - val_mean_squared_error: 0.0617
# Epoch 39/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0603 - acc: 0.9280 - mean_absolute_error: 0.1728 - mean_squared_error: 0.0603 - val_loss: 0.0622 - val_acc: 0.9233 - val_mean_absolute_error: 0.1784 - val_mean_squared_error: 0.0622
# Epoch 40/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0603 - acc: 0.9269 - mean_absolute_error: 0.1730 - mean_squared_error: 0.0603 - val_loss: 0.0615 - val_acc: 0.9277 - val_mean_absolute_error: 0.1760 - val_mean_squared_error: 0.0615
# Epoch 41/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0603 - acc: 0.9272 - mean_absolute_error: 0.1727 - mean_squared_error: 0.0603 - val_loss: 0.0612 - val_acc: 0.9240 - val_mean_absolute_error: 0.1761 - val_mean_squared_error: 0.0612
# Epoch 42/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0603 - acc: 0.9282 - mean_absolute_error: 0.1725 - mean_squared_error: 0.0603 - val_loss: 0.0613 - val_acc: 0.9296 - val_mean_absolute_error: 0.1748 - val_mean_squared_error: 0.0613
# Epoch 43/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0603 - acc: 0.9283 - mean_absolute_error: 0.1726 - mean_squared_error: 0.0603 - val_loss: 0.0619 - val_acc: 0.9281 - val_mean_absolute_error: 0.1780 - val_mean_squared_error: 0.0619
# Epoch 44/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0602 - acc: 0.9281 - mean_absolute_error: 0.1726 - mean_squared_error: 0.0602 - val_loss: 0.0610 - val_acc: 0.9316 - val_mean_absolute_error: 0.1732 - val_mean_squared_error: 0.0610
# Epoch 45/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0602 - acc: 0.9288 - mean_absolute_error: 0.1723 - mean_squared_error: 0.0602 - val_loss: 0.0614 - val_acc: 0.9270 - val_mean_absolute_error: 0.1738 - val_mean_squared_error: 0.0614
# Epoch 46/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0601 - acc: 0.9289 - mean_absolute_error: 0.1723 - mean_squared_error: 0.0601 - val_loss: 0.0619 - val_acc: 0.9284 - val_mean_absolute_error: 0.1754 - val_mean_squared_error: 0.0619
# Epoch 47/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0601 - acc: 0.9298 - mean_absolute_error: 0.1720 - mean_squared_error: 0.0601 - val_loss: 0.0613 - val_acc: 0.9344 - val_mean_absolute_error: 0.1719 - val_mean_squared_error: 0.0613
# Epoch 48/100
# 32000/32000 [==============================] - 1s 42us/sample - loss: 0.0601 - acc: 0.9285 - mean_absolute_error: 0.1722 - mean_squared_error: 0.0601 - val_loss: 0.0611 - val_acc: 0.9336 - val_mean_absolute_error: 0.1743 - val_mean_squared_error: 0.0611
# Epoch 49/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0600 - acc: 0.9284 - mean_absolute_error: 0.1719 - mean_squared_error: 0.0600 - val_loss: 0.0613 - val_acc: 0.9280 - val_mean_absolute_error: 0.1762 - val_mean_squared_error: 0.0613
# Epoch 50/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0600 - acc: 0.9301 - mean_absolute_error: 0.1717 - mean_squared_error: 0.0600 - val_loss: 0.0608 - val_acc: 0.9285 - val_mean_absolute_error: 0.1768 - val_mean_squared_error: 0.0608
# Epoch 51/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0600 - acc: 0.9284 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0600 - val_loss: 0.0609 - val_acc: 0.9286 - val_mean_absolute_error: 0.1748 - val_mean_squared_error: 0.0609
# Epoch 52/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0600 - acc: 0.9298 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0600 - val_loss: 0.0605 - val_acc: 0.9308 - val_mean_absolute_error: 0.1745 - val_mean_squared_error: 0.0605
# Epoch 53/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0600 - acc: 0.9291 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0600 - val_loss: 0.0609 - val_acc: 0.9324 - val_mean_absolute_error: 0.1732 - val_mean_squared_error: 0.0609
# Epoch 54/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0600 - acc: 0.9293 - mean_absolute_error: 0.1718 - mean_squared_error: 0.0600 - val_loss: 0.0614 - val_acc: 0.9339 - val_mean_absolute_error: 0.1772 - val_mean_squared_error: 0.0614
# Epoch 55/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0599 - acc: 0.9296 - mean_absolute_error: 0.1717 - mean_squared_error: 0.0599 - val_loss: 0.0618 - val_acc: 0.9226 - val_mean_absolute_error: 0.1756 - val_mean_squared_error: 0.0618
# Epoch 56/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0599 - acc: 0.9298 - mean_absolute_error: 0.1717 - mean_squared_error: 0.0599 - val_loss: 0.0612 - val_acc: 0.9280 - val_mean_absolute_error: 0.1760 - val_mean_squared_error: 0.0612
# Epoch 57/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0600 - acc: 0.9303 - mean_absolute_error: 0.1719 - mean_squared_error: 0.0600 - val_loss: 0.0611 - val_acc: 0.9335 - val_mean_absolute_error: 0.1753 - val_mean_squared_error: 0.0611
# Epoch 58/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0599 - acc: 0.9297 - mean_absolute_error: 0.1715 - mean_squared_error: 0.0599 - val_loss: 0.0604 - val_acc: 0.9334 - val_mean_absolute_error: 0.1742 - val_mean_squared_error: 0.0604
# Epoch 59/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0598 - acc: 0.9303 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0598 - val_loss: 0.0607 - val_acc: 0.9346 - val_mean_absolute_error: 0.1725 - val_mean_squared_error: 0.0607
# Epoch 60/100
# 32000/32000 [==============================] - 1s 46us/sample - loss: 0.0598 - acc: 0.9291 - mean_absolute_error: 0.1715 - mean_squared_error: 0.0598 - val_loss: 0.0606 - val_acc: 0.9239 - val_mean_absolute_error: 0.1745 - val_mean_squared_error: 0.0606
# Epoch 61/100
# 32000/32000 [==============================] - 2s 50us/sample - loss: 0.0598 - acc: 0.9310 - mean_absolute_error: 0.1715 - mean_squared_error: 0.0598 - val_loss: 0.0621 - val_acc: 0.9350 - val_mean_absolute_error: 0.1744 - val_mean_squared_error: 0.0621
# Epoch 62/100
# 32000/32000 [==============================] - 2s 50us/sample - loss: 0.0598 - acc: 0.9300 - mean_absolute_error: 0.1712 - mean_squared_error: 0.0598 - val_loss: 0.0613 - val_acc: 0.9339 - val_mean_absolute_error: 0.1757 - val_mean_squared_error: 0.0613
# Epoch 63/100
# 32000/32000 [==============================] - 1s 36us/sample - loss: 0.0598 - acc: 0.9301 - mean_absolute_error: 0.1711 - mean_squared_error: 0.0598 - val_loss: 0.0606 - val_acc: 0.9298 - val_mean_absolute_error: 0.1749 - val_mean_squared_error: 0.0606
# Epoch 64/100
# 32000/32000 [==============================] - 1s 33us/sample - loss: 0.0598 - acc: 0.9287 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0598 - val_loss: 0.0604 - val_acc: 0.9373 - val_mean_absolute_error: 0.1734 - val_mean_squared_error: 0.0604
# Epoch 65/100
# 32000/32000 [==============================] - 1s 34us/sample - loss: 0.0598 - acc: 0.9299 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0598 - val_loss: 0.0612 - val_acc: 0.9342 - val_mean_absolute_error: 0.1761 - val_mean_squared_error: 0.0612
# Epoch 66/100
# 32000/32000 [==============================] - 1s 33us/sample - loss: 0.0596 - acc: 0.9302 - mean_absolute_error: 0.1708 - mean_squared_error: 0.0596 - val_loss: 0.0604 - val_acc: 0.9301 - val_mean_absolute_error: 0.1751 - val_mean_squared_error: 0.0604
# Epoch 67/100
# 32000/32000 [==============================] - 1s 34us/sample - loss: 0.0598 - acc: 0.9291 - mean_absolute_error: 0.1712 - mean_squared_error: 0.0598 - val_loss: 0.0606 - val_acc: 0.9342 - val_mean_absolute_error: 0.1743 - val_mean_squared_error: 0.0606
# Epoch 68/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0597 - acc: 0.9299 - mean_absolute_error: 0.1710 - mean_squared_error: 0.0597 - val_loss: 0.0608 - val_acc: 0.9354 - val_mean_absolute_error: 0.1741 - val_mean_squared_error: 0.0608
# Epoch 69/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0596 - acc: 0.9301 - mean_absolute_error: 0.1707 - mean_squared_error: 0.0596 - val_loss: 0.0604 - val_acc: 0.9305 - val_mean_absolute_error: 0.1722 - val_mean_squared_error: 0.0604
# Epoch 70/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0596 - acc: 0.9306 - mean_absolute_error: 0.1705 - mean_squared_error: 0.0596 - val_loss: 0.0603 - val_acc: 0.9366 - val_mean_absolute_error: 0.1719 - val_mean_squared_error: 0.0603
# Epoch 71/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0596 - acc: 0.9300 - mean_absolute_error: 0.1706 - mean_squared_error: 0.0596 - val_loss: 0.0604 - val_acc: 0.9327 - val_mean_absolute_error: 0.1725 - val_mean_squared_error: 0.0604
# Epoch 72/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0595 - acc: 0.9302 - mean_absolute_error: 0.1702 - mean_squared_error: 0.0595 - val_loss: 0.0609 - val_acc: 0.9269 - val_mean_absolute_error: 0.1745 - val_mean_squared_error: 0.0609
# Epoch 73/100
# 32000/32000 [==============================] - 2s 48us/sample - loss: 0.0595 - acc: 0.9304 - mean_absolute_error: 0.1704 - mean_squared_error: 0.0595 - val_loss: 0.0604 - val_acc: 0.9310 - val_mean_absolute_error: 0.1711 - val_mean_squared_error: 0.0604
# Epoch 74/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0595 - acc: 0.9302 - mean_absolute_error: 0.1703 - mean_squared_error: 0.0595 - val_loss: 0.0606 - val_acc: 0.9350 - val_mean_absolute_error: 0.1729 - val_mean_squared_error: 0.0606
# Epoch 75/100
# 32000/32000 [==============================] - 1s 34us/sample - loss: 0.0595 - acc: 0.9305 - mean_absolute_error: 0.1702 - mean_squared_error: 0.0595 - val_loss: 0.0607 - val_acc: 0.9337 - val_mean_absolute_error: 0.1738 - val_mean_squared_error: 0.0607
# Epoch 76/100
# 32000/32000 [==============================] - 1s 34us/sample - loss: 0.0595 - acc: 0.9289 - mean_absolute_error: 0.1704 - mean_squared_error: 0.0595 - val_loss: 0.0606 - val_acc: 0.9286 - val_mean_absolute_error: 0.1704 - val_mean_squared_error: 0.0606
# Epoch 77/100
# 32000/32000 [==============================] - 1s 36us/sample - loss: 0.0595 - acc: 0.9302 - mean_absolute_error: 0.1702 - mean_squared_error: 0.0595 - val_loss: 0.0603 - val_acc: 0.9310 - val_mean_absolute_error: 0.1701 - val_mean_squared_error: 0.0603
# Epoch 78/100
# 32000/32000 [==============================] - 1s 36us/sample - loss: 0.0595 - acc: 0.9303 - mean_absolute_error: 0.1700 - mean_squared_error: 0.0595 - val_loss: 0.0600 - val_acc: 0.9358 - val_mean_absolute_error: 0.1721 - val_mean_squared_error: 0.0600
# Epoch 79/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9301 - mean_absolute_error: 0.1700 - mean_squared_error: 0.0594 - val_loss: 0.0609 - val_acc: 0.9374 - val_mean_absolute_error: 0.1736 - val_mean_squared_error: 0.0609
# Epoch 80/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9310 - mean_absolute_error: 0.1699 - mean_squared_error: 0.0594 - val_loss: 0.0612 - val_acc: 0.9351 - val_mean_absolute_error: 0.1729 - val_mean_squared_error: 0.0612
# Epoch 81/100
# 32000/32000 [==============================] - 1s 34us/sample - loss: 0.0594 - acc: 0.9301 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0594 - val_loss: 0.0611 - val_acc: 0.9351 - val_mean_absolute_error: 0.1746 - val_mean_squared_error: 0.0611
# Epoch 82/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9305 - mean_absolute_error: 0.1700 - mean_squared_error: 0.0594 - val_loss: 0.0605 - val_acc: 0.9323 - val_mean_absolute_error: 0.1738 - val_mean_squared_error: 0.0605
# Epoch 83/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9299 - mean_absolute_error: 0.1700 - mean_squared_error: 0.0594 - val_loss: 0.0600 - val_acc: 0.9324 - val_mean_absolute_error: 0.1715 - val_mean_squared_error: 0.0600
# Epoch 84/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0593 - acc: 0.9307 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0593 - val_loss: 0.0610 - val_acc: 0.9251 - val_mean_absolute_error: 0.1729 - val_mean_squared_error: 0.0610
# Epoch 85/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9304 - mean_absolute_error: 0.1700 - mean_squared_error: 0.0594 - val_loss: 0.0603 - val_acc: 0.9316 - val_mean_absolute_error: 0.1713 - val_mean_squared_error: 0.0603
# Epoch 86/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9309 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0594 - val_loss: 0.0601 - val_acc: 0.9350 - val_mean_absolute_error: 0.1733 - val_mean_squared_error: 0.0601
# Epoch 87/100
# 32000/32000 [==============================] - 1s 36us/sample - loss: 0.0593 - acc: 0.9308 - mean_absolute_error: 0.1698 - mean_squared_error: 0.0593 - val_loss: 0.0601 - val_acc: 0.9295 - val_mean_absolute_error: 0.1738 - val_mean_squared_error: 0.0601
# Epoch 88/100
# 32000/32000 [==============================] - 1s 40us/sample - loss: 0.0593 - acc: 0.9305 - mean_absolute_error: 0.1697 - mean_squared_error: 0.0593 - val_loss: 0.0617 - val_acc: 0.9361 - val_mean_absolute_error: 0.1775 - val_mean_squared_error: 0.0617
# Epoch 89/100
# 32000/32000 [==============================] - 1s 35us/sample - loss: 0.0594 - acc: 0.9304 - mean_absolute_error: 0.1699 - mean_squared_error: 0.0594 - val_loss: 0.0599 - val_acc: 0.9337 - val_mean_absolute_error: 0.1697 - val_mean_squared_error: 0.0599
# Epoch 90/100
# 32000/32000 [==============================] - 1s 36us/sample - loss: 0.0594 - acc: 0.9307 - mean_absolute_error: 0.1700 - mean_squared_error: 0.0594 - val_loss: 0.0601 - val_acc: 0.9319 - val_mean_absolute_error: 0.1715 - val_mean_squared_error: 0.0601
# Epoch 91/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0593 - acc: 0.9303 - mean_absolute_error: 0.1697 - mean_squared_error: 0.0593 - val_loss: 0.0598 - val_acc: 0.9308 - val_mean_absolute_error: 0.1731 - val_mean_squared_error: 0.0598
# Epoch 92/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0593 - acc: 0.9297 - mean_absolute_error: 0.1696 - mean_squared_error: 0.0593 - val_loss: 0.0607 - val_acc: 0.9250 - val_mean_absolute_error: 0.1757 - val_mean_squared_error: 0.0607
# Epoch 93/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0592 - acc: 0.9297 - mean_absolute_error: 0.1694 - mean_squared_error: 0.0592 - val_loss: 0.0599 - val_acc: 0.9289 - val_mean_absolute_error: 0.1724 - val_mean_squared_error: 0.0599
# Epoch 94/100
# 32000/32000 [==============================] - 1s 38us/sample - loss: 0.0593 - acc: 0.9299 - mean_absolute_error: 0.1696 - mean_squared_error: 0.0593 - val_loss: 0.0602 - val_acc: 0.9354 - val_mean_absolute_error: 0.1712 - val_mean_squared_error: 0.0602
# Epoch 95/100
# 32000/32000 [==============================] - 1s 36us/sample - loss: 0.0592 - acc: 0.9304 - mean_absolute_error: 0.1695 - mean_squared_error: 0.0592 - val_loss: 0.0598 - val_acc: 0.9323 - val_mean_absolute_error: 0.1699 - val_mean_squared_error: 0.0598
# Epoch 96/100
# 32000/32000 [==============================] - 1s 37us/sample - loss: 0.0592 - acc: 0.9303 - mean_absolute_error: 0.1693 - mean_squared_error: 0.0592 - val_loss: 0.0609 - val_acc: 0.9260 - val_mean_absolute_error: 0.1711 - val_mean_squared_error: 0.0609
# Epoch 97/100
# 32000/32000 [==============================] - 1s 41us/sample - loss: 0.0592 - acc: 0.9298 - mean_absolute_error: 0.1692 - mean_squared_error: 0.0592 - val_loss: 0.0601 - val_acc: 0.9324 - val_mean_absolute_error: 0.1753 - val_mean_squared_error: 0.0601
# Epoch 98/100
# 32000/32000 [==============================] - 1s 39us/sample - loss: 0.0591 - acc: 0.9302 - mean_absolute_error: 0.1694 - mean_squared_error: 0.0591 - val_loss: 0.0603 - val_acc: 0.9345 - val_mean_absolute_error: 0.1707 - val_mean_squared_error: 0.0603
# Epoch 99/100
# 32000/32000 [==============================] - 2s 50us/sample - loss: 0.0591 - acc: 0.9310 - mean_absolute_error: 0.1693 - mean_squared_error: 0.0591 - val_loss: 0.0602 - val_acc: 0.9383 - val_mean_absolute_error: 0.1714 - val_mean_squared_error: 0.0602
# Epoch 100/100
# 32000/32000 [==============================] - 2s 54us/sample - loss: 0.0592 - acc: 0.9301 - mean_absolute_error: 0.1692 - mean_squared_error: 0.0592 - val_loss: 0.0601 - val_acc: 0.9295 - val_mean_absolute_error: 0.1721 - val_mean_squared_error: 0.0601

# %%
# This section is for interesting plots


# The first plot is of the loss and the validation loss. These ought to decrease rapidly in the first few epochs and should be close together. 
# At some point, the ANN doesn't improve so much anymore. The losses behave randomly there, as improvement is no longer possible
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss throughout training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Loss','Val_loss'],loc='upper right')
plt.show()

# The second plot is of the true label values and the predicted label values
# We generate a prediction value using the trained model here.
# The choice to use normalized data or not should be consistent with earlier choices
test_predictions = model.predict(test_features)
# What is desired is a plot with a clear straight line with slope 1
# Such a result shows that the predictions are close to the real values
# print(test_labels)

plt.scatter(test_labels.Depth, test_predictions[:,0])
plt.scatter(test_labels.Depth, test_labels.Depth)
plt.title('Result accuracy of the ANN: Normalized Depth')
plt.xlabel('True Values [m]')
plt.ylabel('ANN output values [m]')
plt.show()

plt.scatter(test_labels.Shape, test_predictions[:,1])
plt.title('Result accuracy of the ANN: Shape')
plt.xlabel('True Values [-]')
plt.ylabel('ANN output values [-]')
plt.show()

# %%
model.predict(test_features[1]).flatten()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\specialTopics\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-e149a1ed6a92> in <module>
# ----> 1 model.predict(test_features[1]).flatten()
#
# ~\Anaconda3\envs\specialTopics\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\specialTopics\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
